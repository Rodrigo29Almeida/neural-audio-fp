# %%
import os
import sys
import numpy as np
import tensorflow as tf
import yaml
import h5py
import glob
from tensorflow.keras.utils import Progbar
from model_RA.dataset_RA import Dataset
from model_RA.fp_RA.melspec.melspectrogram_RA import get_melspec_layer
from model_RA.fp_RA.nnfp import get_fingerprinter
import soundfile as sf
# Out:
# 2024-06-18 15:39:00.902964: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# After run, the output (generated fingerprints) directory will be: <br>
# $\;\;\;\;\;\;$    .<br>
# $\;\;\;\;\;\;$    └──dataset<br>
# $\;\;\;\;\;\;\;\;\;\;\;\;$        └── dummy_db<br>
# $\;\;\;\;\;\;\;\;\;\;\;\;$            └── 000<br>
# $\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;$                ├── 000001.h5<br>
# $\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;$                ├── 000002.h5<br>
# $\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;$                └── 000003.h5<br>
# $\;\;\;\;\;\;\;\;\;\;\;\;$            └── 001<br>
# $\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;$                ├── 001001.h5<br>
# $\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;$                ├── 001002.h5<br>
# $\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;$                └── 001003.h5

# %%
def load_config(config_fname):
    config_filepath = './config/' + config_fname + '.yaml'
    if os.path.exists(config_filepath):
        print(f'cli: Configuration from {config_filepath}')
    else:
        sys.exit(f'cli: ERROR! Configuration file {config_filepath} is missing!!')

    with open(config_filepath, 'r') as f:
        cfg = yaml.safe_load(f)
    return cfg

def load_checkpoint(checkpoint_root_dir, checkpoint_name, checkpoint_index,
                    m_fp):
    """ Load a trained fingerprinter """
    # Create checkpoint
    checkpoint = tf.train.Checkpoint(model=m_fp)
    checkpoint_dir = checkpoint_root_dir + f'/{checkpoint_name}/'
    c_manager = tf.train.CheckpointManager(checkpoint, checkpoint_dir,
                                           max_to_keep=None)

    # Load
    if checkpoint_index == None:
        tf.print("\x1b[1;32mArgument 'checkpoint_index' was not specified.\x1b[0m")
        tf.print('\x1b[1;32mSearching for the latest checkpoint...\x1b[0m')
        latest_checkpoint = c_manager.latest_checkpoint
        if latest_checkpoint:
            checkpoint_index = int(latest_checkpoint.split(sep='ckpt-')[-1])
            status = checkpoint.restore(latest_checkpoint)
            status.expect_partial()
            tf.print(f'---Restored from {c_manager.latest_checkpoint}---')
        else:
            raise FileNotFoundError(f'Cannot find checkpoint in {checkpoint_dir}')
    else:
        checkpoint_fpath = checkpoint_dir + 'ckpt-' + str(checkpoint_index)
        status = checkpoint.restore(checkpoint_fpath) # Let TF to handle error cases.
        status.expect_partial()
        tf.print(f'---Restored from {checkpoint_fpath}---')
    return checkpoint_index


def prevent_overwrite(key, target_path):
    if (key == 'dummy_db') & os.path.exists(target_path):
        answer = input(f'{target_path} exists. Will you overwrite (y/N)?')
        if answer.lower() not in ['y', 'yes']: sys.exit()

# %%
def build_fp(cfg):
    """ Build fingerprinter """
    # m_pre: log-power-Mel-spectrogram layer, S.
    m_pre = get_melspec_layer(cfg, trainable=False)

    # m_fp: fingerprinter g(f(.)).
    m_fp = get_fingerprinter(cfg, trainable=False)
    return m_pre, m_fp

@tf.function
def test_step(X, m_pre, m_fp):
    """ Test step used for generating fingerprint """
    # X is not (Xa, Xp) here. The second element is reduced now.
    m_fp.trainable = False
    return m_fp(m_pre(X))  # (BSZ, Dim)

# %%
def load_audio(file_path):
    audio, _ = sf.read(file_path)
    
    if audio.ndim > 1:
        audio = np.mean(audio, axis=1)  # Convertendo para mono se necessário
    # Normalizar o áudio
    audio = audio / np.max(np.abs(audio))
    return audio

# %%
#file_path = '/mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000003.wav'
#x = load_audio(file_path)

# %%
def split_audio_into_segments(audio, segment_duration=1.0, hop_size=0.5, sample_rate=8000):
    segment_samples = int(segment_duration * sample_rate)
    hop_samples = int(hop_size * sample_rate)

    segments = []
    for start in range(0, len(audio) - segment_samples + 1, hop_samples):
        segment = audio[start:start + segment_samples]
        if len(segment) == segment_samples:
            segments.append(segment)
    
    return segments

# %%
#segments = split_audio_into_segments(x, segment_duration=1.0, hop_size=0.5, sample_rate=8000)
#X = tf.convert_to_tensor(segments, dtype=tf.float32) #473,8000
#tensor_transformado = tf.expand_dims(tf.expand_dims(X, axis=0), axis=0)
#tensores_transformados = [tf.expand_dims(tf.expand_dims(tensor, axis=0), axis=0) for tensor in X]

# %%
config = "default_RA"
cfg = load_config(config)
checkpoint_name:str='CHECK_BFTRI_100'
checkpoint_index:int=101
source_root_dir = cfg['DIR']['SOURCE_ROOT_DIR']
output_root_dir:str='/mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db'

# Build and load checkpoint
m_pre, m_fp = build_fp(cfg)
checkpoint_root_dir = cfg['DIR']['LOG_ROOT_DIR'] + 'checkpoint/'
checkpoint_index = load_checkpoint(checkpoint_root_dir, checkpoint_name,
                                    checkpoint_index, m_fp)
# Out:
# cli: Configuration from ./config/default_RA.yaml
# ---Restored from ./logs/checkpoint//CHECK_BFTRI_100/ckpt-101---

# %%
def process_audio_files(source_root_dir, output_root_dir, m_pre, m_fp):
    audio_files = sorted(glob.glob(source_root_dir + 'test-dummy-db-100k-full/' + '**/*.wav', recursive=True))
    for file_path in audio_files:
        base_name = os.path.splitext(os.path.basename(file_path))[0]

        audio = load_audio(file_path)
        segments = split_audio_into_segments(audio, segment_duration=1.0, hop_size=0.5, sample_rate=8000)
        X = tf.convert_to_tensor(segments, dtype=tf.float32)
        tensores_transformados = [tf.expand_dims(tf.expand_dims(tensor, axis=0), axis=0) for tensor in X]

        emb = []
        for i in range(len(X)):
            embedding = test_step(tensores_transformados[i], m_pre, m_fp)
            emb.append(embedding.numpy())
        
        emb_array = np.array(emb)

        output_file_path = os.path.join(output_root_dir, base_name + '.h5')
        os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

        with h5py.File(output_file_path, 'w') as hf:
            hf.create_dataset('embeddings', data=emb_array)

# %%
process_audio_files(source_root_dir, output_root_dir, m_pre, m_fp)
#430034(?)

#93458 musicas
# Out:
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000003.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000003.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000020.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000020.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000026.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000026.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000030.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000030.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000046.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000046.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000048.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000048.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000135.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000135.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000136.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000136.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000137.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000137.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000138.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000138.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000139.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000139.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000142.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000142.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000144.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000144.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000145.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000145.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000146.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000146.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000147.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000147.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000149.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000149.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000150.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000150.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000151.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000151.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000152.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000152.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000153.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000153.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000154.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000154.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000155.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000155.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000156.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000156.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000157.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000157.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000158.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000158.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000159.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000159.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000160.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000160.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000161.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000161.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000162.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000162.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000163.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000163.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000164.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000164.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000165.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000165.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000166.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000166.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000167.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000167.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000168.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000168.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000169.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000169.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000170.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000170.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000171.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000171.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000172.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000172.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000173.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000173.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000174.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000174.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000175.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000175.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000176.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000176.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000177.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000177.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000178.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000178.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000179.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000179.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000181.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000181.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000183.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000183.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000184.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000184.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000185.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000185.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000188.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000188.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000189.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000189.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000191.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000191.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000192.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000192.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000195.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000195.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000196.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000196.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000198.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000198.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000199.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000199.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000201.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000201.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000202.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000202.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000205.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000205.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000206.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000206.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000208.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000208.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000209.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000209.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000226.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000226.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000228.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000228.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000236.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000236.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000237.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000237.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000238.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000238.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000246.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000246.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000247.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000247.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000248.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000248.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000249.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000249.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000250.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000250.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000251.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000251.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000252.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000252.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000253.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000253.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000254.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000254.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000257.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000257.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000258.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000258.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000273.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000273.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000274.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000274.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000275.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000275.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000276.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000276.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000277.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000277.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000281.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000281.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000282.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000282.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000284.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000284.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000285.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000285.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000293.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000293.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000294.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000294.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000297.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000297.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000300.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000300.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000303.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000303.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000304.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000304.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000305.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000305.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000306.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000306.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000307.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000307.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000308.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000308.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000309.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000309.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000310.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000310.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000311.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000311.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000312.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000312.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000313.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000313.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000314.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000314.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000315.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000315.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000316.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000316.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000317.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000317.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000318.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000318.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000319.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000319.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000320.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000320.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000321.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000321.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000322.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000322.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000323.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000323.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000324.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000324.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000325.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000325.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000326.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000326.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000327.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000327.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000328.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000328.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000330.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000330.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000331.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000331.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000332.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000332.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000333.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000333.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000334.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000334.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000335.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000335.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000336.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000336.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000337.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000337.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000338.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000338.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000339.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000339.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000340.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000340.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000341.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000341.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000342.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000342.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000343.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000343.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000344.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000344.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000345.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000345.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000346.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000346.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000347.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000347.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000348.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000348.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000349.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000349.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000350.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000350.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000351.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000351.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000353.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000353.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000354.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000354.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000355.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000355.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000356.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000356.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000357.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000357.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000358.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000358.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000359.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000359.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000360.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000360.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000361.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000361.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000362.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000362.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000363.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000363.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000364.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000364.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000365.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000365.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000366.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000366.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000367.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000367.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000369.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000369.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000370.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000370.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000371.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000371.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000384.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000384.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000385.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000385.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000386.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000386.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000387.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000387.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000393.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000393.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000394.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000394.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000395.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000395.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000396.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000396.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000397.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000397.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000398.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000398.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000399.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000399.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000401.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000401.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000402.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000402.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000403.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000403.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000404.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000404.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000405.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000405.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000406.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000406.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000407.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000407.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000408.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000408.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000410.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000410.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000411.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000411.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000412.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000412.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000414.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000414.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000416.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000416.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000417.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000417.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000418.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000418.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000419.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000419.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000420.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000420.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000421.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000421.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000422.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000422.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000423.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000423.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000425.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000425.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000426.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000426.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000427.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000427.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000428.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000428.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000429.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000429.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000430.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000430.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000431.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000431.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000432.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000432.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000433.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000433.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000434.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000434.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000435.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000435.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000436.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000436.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000437.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000437.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000438.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000438.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000439.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000439.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000441.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000441.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000442.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000442.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000443.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000443.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000444.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000444.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000445.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000445.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000446.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000446.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000447.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000447.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000448.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000448.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000450.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000450.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000451.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000451.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000452.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000452.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000461.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000461.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000462.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000462.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000463.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000463.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000464.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000464.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000465.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000465.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000466.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000466.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000467.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000467.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000468.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000468.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000469.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000469.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000470.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000470.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000471.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000471.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000472.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000472.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000473.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000473.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000474.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000474.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000475.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000475.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000476.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000476.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000477.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000477.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000478.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000478.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000479.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000479.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000480.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000480.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000481.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/000481.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/000/000482.wav
# ...
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011603.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011604.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011604.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011605.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011605.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011606.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011606.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011608.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011608.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011609.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011609.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011612.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011612.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011613.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011613.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011614.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011614.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011615.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011615.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011616.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011616.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011617.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011617.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011618.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011618.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011619.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011619.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011621.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011621.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011622.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011622.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011623.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011623.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011624.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011624.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011625.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011625.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011626.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011626.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011628.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011628.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011630.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011630.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011631.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011631.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011632.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011632.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011633.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011633.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011634.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011634.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011636.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011636.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011637.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011637.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011640.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011640.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011641.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011641.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011642.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011642.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011643.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011643.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011644.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011644.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011645.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011645.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011648.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011648.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011649.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011649.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011650.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011650.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011651.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011651.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011652.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011652.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011653.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011653.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011655.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011655.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011656.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011656.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011657.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011657.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011660.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011660.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011661.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011661.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011662.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011662.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011663.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011663.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011664.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011664.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011665.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011665.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011666.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011666.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011667.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011667.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011668.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011668.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011669.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011669.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011676.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011676.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011678.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011678.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011680.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011680.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011684.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011684.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011685.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011685.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011686.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011686.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011687.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011687.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011688.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011688.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011689.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011689.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011690.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011690.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011691.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011691.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011692.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011692.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011695.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011695.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011696.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011696.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011697.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011697.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011698.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011698.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011699.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011699.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011700.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011700.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011701.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011701.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011702.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011702.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011703.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011703.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011711.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011711.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011712.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011712.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011713.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011713.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011715.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011715.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011716.wav
# Saved /mnt/dataset/public/Fingerprinting/Embeddings_BFTRI/dummy_db/011716.h5
# file_path: /mnt/dataset/public/Fingerprinting/neural-audio-fp-dataset/music/test-dummy-db-100k-full/fma_full/011/011717.wav
